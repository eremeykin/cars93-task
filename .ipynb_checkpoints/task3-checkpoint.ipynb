# %% [markdown]
# #  Импорт библиотек

# %%
import pandas as pd
import numpy as np
from numpy.linalg import svd as np_svd
from matplotlib import pyplot as plt
from sklearn.feature_selection import mutual_info_classif as MI
from IPython.display import display
from math import sqrt
from itertools import cycle
from sklearn.metrics import *
from pprint import pprint
from sklearn.preprocessing import LabelEncoder

# %%
RANDOM_STATE=345234 # задание генератора
pd.set_option('display.max_rows', 10)
pd.set_option('display.max_columns', 28)

# %% [markdown]
# # Loading Data

# %% [markdown]
# ### Load data from csv file

# %%
data_table = pd.read_csv("cars.csv", index_col=0) # load data from csv
cars = data_table.copy()

# %% [markdown]
# ### Data shape

# %%
data_table.shape
# Out:
# (93, 27)

# %% [markdown]
# ### Features string description

# %%
descr = pd.read_csv("format.csv", index_col=0, sep=";")
descr["HasNulls"] = data_table.isnull().any()
pd.set_option('display.max_rows', 28)
pd.set_option('display.max_colwidth', 100)
display(descr)
pd.set_option('display.max_rows', 8)
pd.set_option('display.max_colwidth', 50)
# Out:
#                            type  \
# feature
# Manufacturer        categorical
# Model               categorical
# Type                categorical
# Min.Price             numerical
# Price                 numerical
# Max.Price             numerical
# MPG.city              numerical
# MPG.highway           numerical
# AirBags             categorical
# DriveTrain          categorical
# Cylinders           categorical
# EngineSize            numerical
# Horsepower            numerical
# RPM                   numerical
# Rev.per.mile          numerical
# Man.trans.avail     categorical
# Fuel.tank.capacity    numerical
# Passengers            numerical
# Length                numerical
# Wheelbase             numerical
# Width                 numerical
# Turn.circle           numerical
# Rear.seat.room        numerical
# Luggage.room          numerical
# Weight                numerical
# Origin              categorical
# Make                categorical
#
#                                                                                                description  \
# feature
# Manufacturer                                                                                 Manufacturer.
# Model                                                                                               Model.
# Type                Type: a factor with levels "Small", "Sporty", "Compact", "Midsize", "Large" and "Van".
# Min.Price                                           Minimum Price (in \$1,000): price for a basic version.
# Price                                     Midrange Price (in \$1,000): average of Min.Price and Max.Price.
# Max.Price                                       Maximum Price (in \$1,000): price for “a premium version”.
# MPG.city                                                     City MPG (miles per US gallon by EPA rating).
# MPG.highway                                                                                   Highway MPG.
# AirBags                               Air Bags standard. Factor: none, driver only, or driver & passenger.
# DriveTrain                                      Drive train type: rear wheel, front wheel or 4WD (factor).
# Cylinders                         Number of cylinders (missing for Mazda RX-7, which has a rotary engine).
# EngineSize                                                                           Engine size (litres).
# Horsepower                                                                           Horsepower (maximum).
# RPM                                                           RPM (revs per minute at maximum horsepower).
# Rev.per.mile                                                Engine revolutions per mile (in highest gear).
# Man.trans.avail                           Is a manual transmission version available? (yes or no, Factor).
# Fuel.tank.capacity                                                        Fuel tank capacity (US gallons).
# Passengers                                                                    Passenger capacity (persons)
# Length                                                                                    Length (inches).
# Wheelbase                                                                              Wheelbase (inches).
# Width                                                                                      Width (inches).
# Turn.circle                                                                           U-turn space (feet).
# Rear.seat.room                                    Rear seat room (inches) (missing for 2-seater vehicles).
# Luggage.room                                             Luggage capacity (cubic feet) (missing for vans).
# Weight                                                                                    Weight (pounds).
# Origin                                                        Of non-USA or USA company origins? (factor).
# Make                                                    Combination of Manufacturer and Model (character).
#
#                     HasNulls
# feature
# Manufacturer           False
# Model                  False
# Type                   False
# Min.Price              False
# Price                  False
# Max.Price              False
# MPG.city                True
# MPG.highway            False
# AirBags                 True
# DriveTrain             False
# Cylinders              False
# EngineSize             False
# Horsepower             False
# RPM                    False
# Rev.per.mile           False
# Man.trans.avail        False
# Fuel.tank.capacity     False
# Passengers             False
# Length                 False
# Wheelbase              False
# Width                  False
# Turn.circle            False
# Rear.seat.room          True
# Luggage.room            True
# Weight                 False
# Origin                 False
# Make                   False

# %% [markdown]
# ### Table represenation

# %%
data_table
# Out:
#    Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 1         Acura  Integra    Small       12.9   15.9       18.8      25.0
# 2         Acura   Legend  Midsize       29.2   33.9       38.7      18.0
# 3          Audi       90  Compact       25.9   29.1       32.3      20.0
# 4          Audi      100  Midsize       30.8   37.7       44.6      19.0
# ..          ...      ...      ...        ...    ...        ...       ...
# 90   Volkswagen   Passat  Compact       17.6   20.0       22.4      21.0
# 91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7      18.0
# 92        Volvo      240  Compact       21.8   22.7       23.5      21.0
# 93        Volvo      850  Midsize       24.8   26.7       28.5      20.0
#
#     MPG.highway             AirBags DriveTrain Cylinders  EngineSize  \
# 1            31                None      Front         4         1.8
# 2            25                 NaN      Front         6         3.2
# 3            26         Driver only      Front         6         2.8
# 4            26  Driver & Passenger      Front         6         2.8
# ..          ...                 ...        ...       ...         ...
# 90           30                None      Front         4         2.0
# 91           25                 NaN      Front         6         2.8
# 92           28         Driver only       Rear         4         2.3
# 93           28  Driver & Passenger      Front         5         2.4
#
#     Horsepower   RPM  Rev.per.mile Man.trans.avail  Fuel.tank.capacity  \
# 1          140  6300          2890             Yes                13.2
# 2          200  5500          2335             Yes                18.0
# 3          172  5500          2280             Yes                16.9
# 4          172  5500          2535             Yes                21.1
# ..         ...   ...           ...             ...                 ...
# 90         134  5800          2685             Yes                18.5
# 91         178  5800          2385             Yes                18.5
# 92         114  5400          2215             Yes                15.8
# 93         168  6200          2310             Yes                19.3
#
#     Passengers  Length  Wheelbase  Width  Turn.circle  Rear.seat.room  \
# 1            5     177        102     68           37            26.5
# 2            5     195        115     71           38            30.0
# 3            5     180        102     67           37            28.0
# 4            6     193        106     70           37            31.0
# ..         ...     ...        ...    ...          ...             ...
# 90           5     180        103     67           35            31.5
# 91           4     159         97     66           36            26.0
# 92           5     190        104     67           37            29.5
# 93           5     184        105     69           38            30.0
#
#     Luggage.room  Weight   Origin                Make
# 1           11.0    2705  non-USA       Acura Integra
# 2           15.0    3560  non-USA        Acura Legend
# 3           14.0    3375  non-USA             Audi 90
# 4           17.0    3405  non-USA            Audi 100
# ..           ...     ...      ...                 ...
# 90          14.0    2985  non-USA   Volkswagen Passat
# 91          15.0    2810  non-USA  Volkswagen Corrado
# 92          14.0    2985  non-USA           Volvo 240
# 93          15.0    3245  non-USA           Volvo 850
#
# [93 rows x 27 columns]

# %% [markdown]
# # Data Study

# %% [markdown]
# ### Description of numerical features

# %%
data_table.describe()
# Out:
#        Min.Price      Price  Max.Price   MPG.city  MPG.highway  EngineSize  \
# count  93.000000  93.000000  93.000000  87.000000    93.000000   93.000000
# mean   17.125806  19.509677  21.898925  22.333333    29.086022    2.667742
# std     8.746029   9.659430  11.030457   5.474394     5.331726    1.037363
# min     6.700000   7.400000   7.900000  15.000000    20.000000    1.000000
# 25%    10.800000  12.200000  14.700000  18.000000    26.000000    1.800000
# 50%    14.700000  17.700000  19.600000  21.000000    28.000000    2.400000
# 75%    20.300000  23.300000  25.300000  25.000000    31.000000    3.300000
# max    45.400000  61.900000  80.000000  46.000000    50.000000    5.700000
#
#        Horsepower          RPM  Rev.per.mile  Fuel.tank.capacity  Passengers  \
# count   93.000000    93.000000     93.000000           93.000000   93.000000
# mean   143.827957  5280.645161   2332.204301           16.664516    5.086022
# std     52.374410   596.731690    496.506525            3.279370    1.038979
# min     55.000000  3800.000000   1320.000000            9.200000    2.000000
# 25%    103.000000  4800.000000   1985.000000           14.500000    4.000000
# 50%    140.000000  5200.000000   2340.000000           16.400000    5.000000
# 75%    170.000000  5750.000000   2565.000000           18.800000    6.000000
# max    300.000000  6500.000000   3755.000000           27.000000    8.000000
#
#            Length   Wheelbase      Width  Turn.circle  Rear.seat.room  \
# count   93.000000   93.000000  93.000000    93.000000       91.000000
# mean   183.204301  103.946237  69.376344    38.956989       27.829670
# std     14.602382    6.819674   3.778986     3.223265        2.989072
# min    141.000000   90.000000  60.000000    32.000000       19.000000
# 25%    174.000000   98.000000  67.000000    37.000000       26.000000
# 50%    183.000000  103.000000  69.000000    39.000000       27.500000
# 75%    192.000000  110.000000  72.000000    41.000000       30.000000
# max    219.000000  119.000000  78.000000    45.000000       36.000000
#
#        Luggage.room       Weight
# count     82.000000    93.000000
# mean      13.890244  3072.903226
# std        2.997967   589.896510
# min        6.000000  1695.000000
# 25%       12.000000  2620.000000
# 50%       14.000000  3040.000000
# 75%       15.000000  3525.000000
# max       22.000000  4105.000000

# %% [markdown]
# ### Description of categorical features

# %%
data_table.describe(include=[np.object])
# Out:
#        Manufacturer Model     Type      AirBags DriveTrain Cylinders  \
# count            93    93       93           87         93        93
# unique           32    93        6            3          3         6
# top            Ford  190E  Midsize  Driver only      Front         4
# freq              8     1       22           40         67        49
#
#        Man.trans.avail Origin           Make
# count               93     93             93
# unique               2      2             93
# top                Yes    USA  Ford Aerostar
# freq                61     48              1

# %% [markdown]
# ### Contingency tables

# %%
pd.set_option('display.max_rows', 33)

cat = [x for x in descr.loc[descr.type=="categorical"].index if x not in ["Manufacturer", "Model", "Make"]]
# cat = [x for x in descr.loc[descr.type=="categorical"].index if x not in  ["Model", "Make"]]
for feature in cat:
    if feature!= "DriveTrain":
        display(pd.crosstab(data_table[feature], data_table.DriveTrain, dropna=False, margins=True))
        
pd.set_option('display.max_rows', 8)
# Out:
# DriveTrain  4WD  Front  Rear  All
# Type
# Compact       1     13     2   16
# Large         0      7     4   11
# Midsize       0     17     5   22
# Small         2     19     0   21
# Sporty        2      7     5   14
# Van           5      4     0    9
# All          10     67    16   93
# DriveTrain          4WD  Front  Rear  All
# AirBags
# Driver & Passenger    0     10     5   15
# Driver only           5     25    10   40
# None                  5     26     1   32
# All                  10     67    16   93
# DriveTrain  4WD  Front  Rear  All
# Cylinders
# 3             1      2     0    3
# 4             4     41     4   49
# 5             0      2     0    2
# 6             5     20     6   31
# 8             0      2     5    7
# rotary        0      0     1    1
# All          10     67    16   93
# DriveTrain       4WD  Front  Rear  All
# Man.trans.avail
# No                 3     22     7   32
# Yes                7     45     9   61
# All               10     67    16   93
# DriveTrain  4WD  Front  Rear  All
# Origin
# USA           5     34     9   48
# non-USA       5     33     7   45
# All          10     67    16   93

# %% [markdown]
# "Origin" feature seems to be useless

# %%
display(data_table.groupby("Cylinders")["Horsepower"].mean())
display(data_table.groupby("Cylinders")["EngineSize"].mean())
display(data_table.groupby("Cylinders")["RPM"].mean())
# Out:
# Cylinders
# 3          66.000000
# 4         113.469388
# 5         138.500000
# 6         175.580645
# 8         234.714286
# rotary    255.000000
# Name: Horsepower, dtype: float64
# Cylinders
# 3         1.166667
# 4         2.020408
# 5         2.450000
# 6         3.403226
# 8         4.842857
# rotary    1.300000
# Name: EngineSize, dtype: float64
# Cylinders
# 3         5766.666667
# 4         5444.897959
# 5         5350.000000
# 6         5022.580645
# 8         4871.428571
# rotary    6500.000000
# Name: RPM, dtype: float64

# %% [markdown]
# Let rotary corresponds to 6 Cylinders now

# %%
for i in cars[cars.Cylinders=="rotary"].index:
    cars.loc[i,"Cylinders"] = 6

# %%
cars["AirBags"][cars["AirBags"].isnull()]="None"
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# # Feature selection

# %%
plt.scatter(data_table.Price, data_table["Min.Price"], color='b', label="Min.Price")
plt.scatter(data_table.Price, data_table["Max.Price"], color='r', label="Max.Price")
plt.plot([0,80],[0,80], color='k')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# "Min.Price", "Max.Price" can be expressed via "Price"

# %%
# LabelEncoder seems to be buggy
def encode(drive_train):
    if drive_train == "Front": return 0
    if drive_train == "Rear": return 1
    if drive_train == "4WD": return 2
    raise Error("Unknown drive_train: {}".format(drive_train))

def decode(code):
    if code == 0: return "Front"
    if code == 1: return "Rear"
    if code == 2: return "4WD"
    raise Error("Unknown code: {}".format(code))
    
target = cars.DriveTrain.copy()
target[target=="Front"]=encode("Front")
target[target=="Rear"]=encode("Rear")
target[target=="4WD"]=encode("4WD")
target = target.astype('int')
target_s = cars.DriveTrain.copy()

# %%
num_features = descr[descr.type=="numerical"].index # numerical features: ['Min.Price','Price','Max.Price', ...,'Weight']
null_features = descr[descr.HasNulls].index # fateures with nulls ['MPG.city','AirBags',...,'Luggage.room']
features = cars[[x for x in num_features if x not in null_features]] # numerical without nulls
mi = MI(features, cars.DriveTrain, random_state=RANDOM_STATE)
mi_threshold = 0.085

remove_features = set(null_features)
for i,f in enumerate(features.columns):
    print("{} mi({:>18s})={:4.3f}".format("   " if mi[i]>0.085 else "[X]", f,mi[i]))
    if mi[i] < mi_threshold:
        remove_features.add(f)
remove_features.update({"Model", "Make", "Origin", "Manufacturer", "Max.Price", "Min.Price", "DriveTrain"})
remove_features.update({"Man.trans.avail","Cylinders", "Type", "AirBags"})
remove_features = remove_features - {"Manufacturer" }
pprint("removed features: {}".format(remove_features))
cars = cars[[x for x in cars.columns if x not in remove_features]]
# Out:
#     mi(         Min.Price)=0.097
#     mi(             Price)=0.088
# [X] mi(         Max.Price)=0.048
#     mi(       MPG.highway)=0.162
#     mi(        EngineSize)=0.118
#     mi(        Horsepower)=0.109
#     mi(               RPM)=0.103
# [X] mi(      Rev.per.mile)=0.079
#     mi(Fuel.tank.capacity)=0.207
#     mi(        Passengers)=0.112
#     mi(            Length)=0.107
# [X] mi(         Wheelbase)=0.019
#     mi(             Width)=0.158
# [X] mi(       Turn.circle)=0.037
#     mi(            Weight)=0.137
# ("removed features: {'Make', 'Rear.seat.room', 'Turn.circle', 'DriveTrain', "
#  "'Rev.per.mile', 'Wheelbase', 'AirBags', 'Model', 'Cylinders', 'Origin', "
#  "'Luggage.room', 'Man.trans.avail', 'Type', 'Min.Price', 'Max.Price', "
#  "'MPG.city'}")

# %% [markdown]
# New description

# %%
pd.set_option('display.max_rows', 28)
pd.set_option('display.max_colwidth', 100)
new_descr = descr.loc[descr.index.isin(cars.columns)]
display(new_descr)
pd.set_option('display.max_rows', 10)
pd.set_option('display.max_colwidth', 50)
# Out:
#                            type  \
# feature
# Manufacturer        categorical
# Price                 numerical
# MPG.highway           numerical
# EngineSize            numerical
# Horsepower            numerical
# RPM                   numerical
# Fuel.tank.capacity    numerical
# Passengers            numerical
# Length                numerical
# Width                 numerical
# Weight                numerical
#
#                                                                          description  \
# feature
# Manufacturer                                                           Manufacturer.
# Price               Midrange Price (in \$1,000): average of Min.Price and Max.Price.
# MPG.highway                                                             Highway MPG.
# EngineSize                                                     Engine size (litres).
# Horsepower                                                     Horsepower (maximum).
# RPM                                     RPM (revs per minute at maximum horsepower).
# Fuel.tank.capacity                                  Fuel tank capacity (US gallons).
# Passengers                                              Passenger capacity (persons)
# Length                                                              Length (inches).
# Width                                                                Width (inches).
# Weight                                                              Weight (pounds).
#
#                     HasNulls
# feature
# Manufacturer           False
# Price                  False
# MPG.highway            False
# EngineSize             False
# Horsepower             False
# RPM                    False
# Fuel.tank.capacity     False
# Passengers             False
# Length                 False
# Width                  False
# Weight                 False

# %% [markdown]
# # Normalization

# %% [markdown]
# One hot encoding

# %%
ncars = cars.copy()
categorical = new_descr[new_descr.type=="categorical"].index
binary_features = dict()
for feature in categorical:
    u_values = ncars[feature].unique()
    for uv in u_values:
        binary_features["{}_{}".format(feature,uv)] = len(u_values)
        ncars["{}_{}".format(feature,uv)] = ncars[feature]== uv
ncars = ncars[[x for x in ncars.columns if x not in categorical]]
ncars
# Out:
#     Price  MPG.highway  EngineSize  Horsepower   RPM  Fuel.tank.capacity  \
# 1    15.9           31         1.8         140  6300                13.2
# 2    33.9           25         3.2         200  5500                18.0
# 3    29.1           26         2.8         172  5500                16.9
# 4    37.7           26         2.8         172  5500                21.1
# 5    30.0           30         3.5         208  5700                21.1
# ..    ...          ...         ...         ...   ...                 ...
# 89   19.7           21         2.5         109  4500                21.1
# 90   20.0           30         2.0         134  5800                18.5
# 91   23.3           25         2.8         178  5800                18.5
# 92   22.7           28         2.3         114  5400                15.8
# 93   26.7           28         2.4         168  6200                19.3
#
#     Passengers  Length  Width  Weight  Manufacturer_Acura  Manufacturer_Audi  \
# 1            5     177     68    2705                True              False
# 2            5     195     71    3560                True              False
# 3            5     180     67    3375               False               True
# 4            6     193     70    3405               False               True
# 5            4     186     69    3640               False              False
# ..         ...     ...    ...     ...                 ...                ...
# 89           7     187     72    3960               False              False
# 90           5     180     67    2985               False              False
# 91           4     159     66    2810               False              False
# 92           5     190     67    2985               False              False
# 93           5     184     69    3245               False              False
#
#     Manufacturer_BMW  Manufacturer_Buick         ...          \
# 1              False               False         ...
# 2              False               False         ...
# 3              False               False         ...
# 4              False               False         ...
# 5               True               False         ...
# ..               ...                 ...         ...
# 89             False               False         ...
# 90             False               False         ...
# 91             False               False         ...
# 92             False               False         ...
# 93             False               False         ...
#
#     Manufacturer_Mercedes-Benz  Manufacturer_Mercury  Manufacturer_Mitsubishi  \
# 1                        False                 False                    False
# 2                        False                 False                    False
# 3                        False                 False                    False
# 4                        False                 False                    False
# 5                        False                 False                    False
# ..                         ...                   ...                      ...
# 89                       False                 False                    False
# 90                       False                 False                    False
# 91                       False                 False                    False
# 92                       False                 False                    False
# 93                       False                 False                    False
#
#     Manufacturer_Nissan  Manufacturer_Oldsmobile  Manufacturer_Plymouth  \
# 1                 False                    False                  False
# 2                 False                    False                  False
# 3                 False                    False                  False
# 4                 False                    False                  False
# 5                 False                    False                  False
# ..                  ...                      ...                    ...
# 89                False                    False                  False
# 90                False                    False                  False
# 91                False                    False                  False
# 92                False                    False                  False
# 93                False                    False                  False
#
#     Manufacturer_Pontiac  Manufacturer_Saab  Manufacturer_Saturn  \
# 1                  False              False                False
# 2                  False              False                False
# 3                  False              False                False
# 4                  False              False                False
# 5                  False              False                False
# ..                   ...                ...                  ...
# 89                 False              False                False
# 90                 False              False                False
# 91                 False              False                False
# 92                 False              False                False
# 93                 False              False                False
#
#     Manufacturer_Subaru  Manufacturer_Suzuki  Manufacturer_Toyota  \
# 1                 False                False                False
# 2                 False                False                False
# 3                 False                False                False
# 4                 False                False                False
# 5                 False                False                False
# ..                  ...                  ...                  ...
# 89                False                False                False
# 90                False                False                False
# 91                False                False                False
# 92                False                False                False
# 93                False                False                False
#
#     Manufacturer_Volkswagen  Manufacturer_Volvo
# 1                     False               False
# 2                     False               False
# 3                     False               False
# 4                     False               False
# 5                     False               False
# ..                      ...                 ...
# 89                     True               False
# 90                     True               False
# 91                     True               False
# 92                    False                True
# 93                    False                True
#
# [93 rows x 42 columns]

# %% [markdown]
# Range and scale transform

# %%
ncars = (ncars-ncars.mean())/(ncars.max()-ncars.min())
for feature, n in binary_features.items():
    ncars[feature] = ncars[feature]/sqrt(n)
display(ncars)
# Out:
#        Price  MPG.highway  EngineSize  Horsepower       RPM  \
# 1  -0.066233     0.063799   -0.184626   -0.015624  0.377539
# 2   0.264043    -0.136201    0.113246    0.229274  0.081243
# 3   0.175969    -0.102867    0.028140    0.114988  0.081243
# 4   0.333767    -0.102867    0.028140    0.114988  0.081243
# 5   0.192483     0.030466    0.177076    0.261927  0.155317
# ..       ...          ...         ...         ...       ...
# 89  0.003492    -0.269534   -0.035690   -0.142155 -0.289128
# 90  0.008997     0.030466   -0.142073   -0.040114  0.192354
# 91  0.069547    -0.136201    0.028140    0.139478  0.192354
# 92  0.058538    -0.036201   -0.078243   -0.121747  0.044205
# 93  0.131933    -0.036201   -0.056966    0.098661  0.340502
#
#     Fuel.tank.capacity  Passengers    Length     Width    Weight  \
# 1            -0.194636   -0.014337 -0.079542 -0.076464 -0.152657
# 2             0.075027   -0.014337  0.151227  0.090203  0.202115
# 3             0.013229   -0.014337 -0.041081 -0.132019  0.125351
# 4             0.249184    0.152330  0.125586  0.034648  0.137799
# 5             0.249184   -0.181004  0.035842 -0.020908  0.235310
# ..                 ...         ...       ...       ...       ...
# 89            0.249184    0.318996  0.048663  0.145759  0.368090
# 90            0.103117   -0.014337 -0.041081 -0.132019 -0.036474
# 91            0.103117   -0.181004 -0.310312 -0.187575 -0.109088
# 92           -0.048568   -0.014337  0.087124 -0.132019 -0.036474
# 93            0.148061   -0.014337  0.010201 -0.020908  0.071409
#
#     Manufacturer_Acura  Manufacturer_Audi  Manufacturer_BMW  \
# 1             0.172975          -0.003802         -0.001901
# 2             0.172975          -0.003802         -0.001901
# 3            -0.003802           0.172975         -0.001901
# 4            -0.003802           0.172975         -0.001901
# 5            -0.003802          -0.003802          0.174876
# ..                 ...                ...               ...
# 89           -0.003802          -0.003802         -0.001901
# 90           -0.003802          -0.003802         -0.001901
# 91           -0.003802          -0.003802         -0.001901
# 92           -0.003802          -0.003802         -0.001901
# 93           -0.003802          -0.003802         -0.001901
#
#     Manufacturer_Buick         ...          Manufacturer_Mercedes-Benz  \
# 1            -0.007603         ...                           -0.003802
# 2            -0.007603         ...                           -0.003802
# 3            -0.007603         ...                           -0.003802
# 4            -0.007603         ...                           -0.003802
# 5            -0.007603         ...                           -0.003802
# ..                 ...         ...                                 ...
# 89           -0.007603         ...                           -0.003802
# 90           -0.007603         ...                           -0.003802
# 91           -0.007603         ...                           -0.003802
# 92           -0.007603         ...                           -0.003802
# 93           -0.007603         ...                           -0.003802
#
#     Manufacturer_Mercury  Manufacturer_Mitsubishi  Manufacturer_Nissan  \
# 1              -0.003802                -0.003802            -0.007603
# 2              -0.003802                -0.003802            -0.007603
# 3              -0.003802                -0.003802            -0.007603
# 4              -0.003802                -0.003802            -0.007603
# 5              -0.003802                -0.003802            -0.007603
# ..                   ...                      ...                  ...
# 89             -0.003802                -0.003802            -0.007603
# 90             -0.003802                -0.003802            -0.007603
# 91             -0.003802                -0.003802            -0.007603
# 92             -0.003802                -0.003802            -0.007603
# 93             -0.003802                -0.003802            -0.007603
#
#     Manufacturer_Oldsmobile  Manufacturer_Plymouth  Manufacturer_Pontiac  \
# 1                 -0.007603              -0.001901             -0.009504
# 2                 -0.007603              -0.001901             -0.009504
# 3                 -0.007603              -0.001901             -0.009504
# 4                 -0.007603              -0.001901             -0.009504
# 5                 -0.007603              -0.001901             -0.009504
# ..                      ...                    ...                   ...
# 89                -0.007603              -0.001901             -0.009504
# 90                -0.007603              -0.001901             -0.009504
# 91                -0.007603              -0.001901             -0.009504
# 92                -0.007603              -0.001901             -0.009504
# 93                -0.007603              -0.001901             -0.009504
#
#     Manufacturer_Saab  Manufacturer_Saturn  Manufacturer_Subaru  \
# 1           -0.001901            -0.001901            -0.005702
# 2           -0.001901            -0.001901            -0.005702
# 3           -0.001901            -0.001901            -0.005702
# 4           -0.001901            -0.001901            -0.005702
# 5           -0.001901            -0.001901            -0.005702
# ..                ...                  ...                  ...
# 89          -0.001901            -0.001901            -0.005702
# 90          -0.001901            -0.001901            -0.005702
# 91          -0.001901            -0.001901            -0.005702
# 92          -0.001901            -0.001901            -0.005702
# 93          -0.001901            -0.001901            -0.005702
#
#     Manufacturer_Suzuki  Manufacturer_Toyota  Manufacturer_Volkswagen  \
# 1             -0.001901            -0.007603                -0.007603
# 2             -0.001901            -0.007603                -0.007603
# 3             -0.001901            -0.007603                -0.007603
# 4             -0.001901            -0.007603                -0.007603
# 5             -0.001901            -0.007603                -0.007603
# ..                  ...                  ...                      ...
# 89            -0.001901            -0.007603                 0.169173
# 90            -0.001901            -0.007603                 0.169173
# 91            -0.001901            -0.007603                 0.169173
# 92            -0.001901            -0.007603                -0.007603
# 93            -0.001901            -0.007603                -0.007603
#
#     Manufacturer_Volvo
# 1            -0.003802
# 2            -0.003802
# 3            -0.003802
# 4            -0.003802
# 5            -0.003802
# ..                 ...
# 89           -0.003802
# 90           -0.003802
# 91           -0.003802
# 92            0.172975
# 93            0.172975
#
# [93 rows x 42 columns]

# %% [markdown]
# # Split train/test

# %%
from sklearn.model_selection import train_test_split
ncars_train, ncars_test, y_train, y_test = train_test_split(ncars, target, test_size=0.33, stratify=target, 
                                                            random_state=RANDOM_STATE)

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn import tree
classifier1 = tree.DecisionTreeClassifier()

# %%
classifier = classifier1
classifier.fit(ncars_train, y=y_train)
y_pred = classifier.predict(ncars_test)

print("test accuracy = {}".format(accuracy_score(y_test, y_pred)))
labels = range(0,3)
index = [decode(x) for x in labels]
c_matrix = pd.DataFrame(confusion_matrix(y_test, y_pred, labels=labels), 
                        index=[x+" actual" for x in index], 
                        columns=[x+" pred" for x in index])
display(c_matrix)
# Out:
# test accuracy = 0.8387096774193549
#               Front pred  Rear pred  4WD pred
# Front actual          21          1         1
# Rear actual            3          2         0
# 4WD actual             0          0         3

# %%
import graphviz
from IPython.core.display import Image, display
dot_data = tree.export_graphviz(classifier, out_file=None, 
                         feature_names=ncars.columns,  
                         class_names=[decode(x) for x in range(0,3)],  
                         filled=True, rounded=True,  
                         special_characters=True)  
graph = graphviz.Source(dot_data, format="png")
graph.render(filename="tree")
display(Image('tree.png'))

# %%
from sklearn.model_selection import cross_val_score
cv_accuracy = cross_val_score(classifier, X=ncars, y=target, cv=10, scoring=make_scorer(accuracy_score)).mean()
print("mean cv accuracy = {}".format(cv_accuracy))
# Out:
# mean cv accuracy = 0.7813888888888888
